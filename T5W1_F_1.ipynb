# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/Datasets/Task (1) Dataset.csv')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2889 entries, 8 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         2889 non-null   object
#  1   Day_of_week                  2889 non-null   object
#  2   Age_band_of_driver           2889 non-null   object
#  3   Sex_of_driver                2889 non-null   object
#  4   Educational_level            2889 non-null   object
#  5   Vehicle_driver_relation      2889 non-null   object
#  6   Driving_experience           2889 non-null   object
#  7   Type_of_vehicle              2889 non-null   object
#  8   Owner_of_vehicle             2889 non-null   object
#  9   Service_year_of_vehicle      2889 non-null   object
#  10  Defect_of_vehicle            2889 non-null   object
#  11  Area_accident_occured        2889 non-null   object
#  12  Lanes_or_Medians             2889 non-null   object
# ...

# %%
df.sample()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 10299  17:11:00      Sunday              31-50          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 10299  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 10299  Lorry (41?100Q)            Owner              Above 10yr  ...
#
#       Vehicle_movement Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 10299   Going straight             na              na                   na
#
#       Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 10299                na            Driver               Normal
#
#       Pedestrian_movement Cause_of_accident Accident_severity
# 10299    Not a Pedestrian     No distancing     Slight Injury
#
# [1 rows x 32 columns]

# %%
df.shape
# Out:
# (12316, 32)

# %% [markdown]
# ### Handle Missing Values

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df=df.dropna(axis=0)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8      17:20:00      Friday              18-30          Male
# 9      17:20:00      Friday              18-30          Male
# 12     17:45:00    Thursday              18-30          Male
# 13     17:45:00    Thursday              31-50          Male
# 14     17:45:00    Thursday              31-50          Male
# ...         ...         ...                ...           ...
# 12302  17:25:00      Friday              31-50          Male
# 12303  12:48:00      Friday              31-50          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 8      Junior high school                Employee         Above 10yr
# 9      Junior high school                Employee              1-2yr
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2928 entries, 8 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         2928 non-null   object
#  1   Day_of_week                  2928 non-null   object
#  2   Age_band_of_driver           2928 non-null   object
#  3   Sex_of_driver                2928 non-null   object
#  4   Educational_level            2928 non-null   object
#  5   Vehicle_driver_relation      2928 non-null   object
#  6   Driving_experience           2928 non-null   object
#  7   Type_of_vehicle              2928 non-null   object
#  8   Owner_of_vehicle             2928 non-null   object
#  9   Service_year_of_vehicle      2928 non-null   object
#  10  Defect_of_vehicle            2928 non-null   object
#  11  Area_accident_occured        2928 non-null   object
#  12  Lanes_or_Medians             2928 non-null   object
# ...

# %%
df['Age_band_of_casualty']
# Out:
# 8        Under 18
# 9           18-30
# 12             na
# 13             na
# 14          18-30
#            ...
# 12302          na
# 12303     Over 51
# 12313       31-50
# 12314          na
# 12315           5
# Name: Age_band_of_casualty, Length: 2889, dtype: object

# %%
df['Time']=pd.to_datetime(df['Time'])
# Out:
# <ipython-input-146-ca8834d81e24>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time']=pd.to_datetime(df['Time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2928 entries, 8 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         2928 non-null   datetime64[ns]
#  1   Day_of_week                  2928 non-null   object
#  2   Age_band_of_driver           2928 non-null   object
#  3   Sex_of_driver                2928 non-null   object
#  4   Educational_level            2928 non-null   object
#  5   Vehicle_driver_relation      2928 non-null   object
#  6   Driving_experience           2928 non-null   object
#  7   Type_of_vehicle              2928 non-null   object
#  8   Owner_of_vehicle             2928 non-null   object
#  9   Service_year_of_vehicle      2928 non-null   object
#  10  Defect_of_vehicle            2928 non-null   object
#  11  Area_accident_occured        2928 non-null   object
#  12  Lanes_or_Medians             2928 non-null   object
# ...

# %%
df['Vehicle_driver_relation']=df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0])
df['Driving_experience']=df['Driving_experience'].fillna(df['Driving_experience'].mode()[0])
df['Type_of_vehicle']=df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0])
df['Owner_of_vehicle']=df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0])
df['Area_accident_occured']=df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0])
df['Road_allignment']=df['Road_allignment'].fillna(df['Road_allignment'].mode()[0])
df['Type_of_collision']=df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0])
df['Vehicle_movement']=df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0])
df['Road_surface_type']=df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0])
df['Educational_level']=df['Educational_level'].fillna(df['Educational_level'].mode()[0])
df['Types_of_Junction']=df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0])
df['Lanes_or_Medians']=df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0])

# %%
df.iloc[5:10]
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 19   8:20:00     Tuesday              18-30          Male  Junior high school
# 21  15:10:00    Thursday              18-30          Male  Junior high school
# 25  18:36:00   Wednesday              18-30          Male  Junior high school
# 27  14:35:00      Friday              18-30          Male   Above high school
# 34  13:57:00    Saturday            Over 51          Male  Junior high school
#
#    Vehicle_driver_relation Driving_experience Type_of_vehicle  \
# 19                Employee          Below 1yr      Long lorry
# 21                Employee              2-5yr  Lorry (11?40Q)
# 25                Employee              2-5yr            Taxi
# 27                Employee              2-5yr      Automobile
# 34                Employee          Below 1yr      Automobile
#
#    Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df['Driving_experience']=df['Driving_experience'].fillna(df['Driving_experience'].mode()[0])

# %%
df['Driving_experience']=df['Driving_experience'].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
df=df.dropna(axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2928 entries, 8 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         2928 non-null   object
#  1   Day_of_week                  2928 non-null   object
#  2   Age_band_of_driver           2928 non-null   object
#  3   Sex_of_driver                2928 non-null   object
#  4   Educational_level            2928 non-null   object
#  5   Vehicle_driver_relation      2928 non-null   object
#  6   Driving_experience           2928 non-null   object
#  7   Type_of_vehicle              2928 non-null   object
#  8   Owner_of_vehicle             2928 non-null   object
#  9   Service_year_of_vehicle      2928 non-null   object
#  10  Defect_of_vehicle            2928 non-null   object
#  11  Area_accident_occured        2928 non-null   object
#  12  Lanes_or_Medians             2928 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience              int64
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Driving_experience  Number_of_vehicles_involved  Number_of_casualties
# count         2889.000000                  2889.000000           2889.000000
# mean             4.314296                     2.011076              1.529249
# std              3.281391                     0.635308              0.993012
# min              1.000000                     1.000000              1.000000
# 25%              1.000000                     2.000000              1.000000
# 50%              5.000000                     2.000000              1.000000
# 75%              5.000000                     2.000000              2.000000
# max             10.000000                     7.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.hist(figsize=(12, 8))
plt.show()

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
# Visualize the distribution of "Type_of_vehicle"
plt.figure(figsize=(10, 6))
df['Type_of_vehicle'].value_counts().plot(kind='bar')
plt.title('Distribution of Vehicle Types')
plt.xlabel('Vehicle Type')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualize the distribution of "Age_band_of_driver"
plt.figure(figsize=(8, 6))
df['Age_band_of_driver'].value_counts().plot(kind='bar')
plt.title('Distribution of Age Band of Drivers')
plt.xlabel('Age Band')
plt.ylabel('Count')
plt.show()

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df.plot.scatter (x='Age_band_of_driver',y = 'Accident_severity')
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='Accident_severity'>

# %%
plt.figure(figsize=(10, 6))
pd.crosstab(df['Age_band_of_driver'], df['Accident_severity']).plot(kind='bar', figsize=(10,6))
plt.title('Relationship between Age Band of Drivers and Accident Severity')
plt.xlabel('Age Band of Drivers')
plt.ylabel('Count')
plt.legend(title='Accident Severity')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %%
numiracal_column=['Number_of_vehicles_involved'	,'Number_of_casualties']

numerical_df=df[numiracal_column]

correlation_matrix=numerical_df.corr()

print(correlation_matrix)
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.231655
# Number_of_casualties                            0.231655              1.000000

# %%
pokemon = pd.DataFrame(df)
pokemon.plot.hexbin(x='Number_of_vehicles_involved', y='Number_of_casualties', title="hixbin Plot of Age band of driver vs Number of casualties" , gridsize=15)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Driving_experience', y='Number_of_casualties', data=df)
plt.title('Relationship between Driving Experience and Number of Casualties')
plt.xlabel('Driving Experience')
plt.ylabel('Number of Casualties')
plt.show()

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12302  17:25:00      Friday              31-50          Male
# 12303  12:48:00      Friday              31-50          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation  Driving_experience  \
# 12302  Junior high school                Employee                   5
# 12303  Junior high school                Employee                   2
# 12313  Junior high school                Employee                   5
# 12314  Junior high school                Employee                  10
# 12315  Junior high school                Employee                   5
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12302       Automobile            Owner                   1-2yr  ...
# ...

# %%
df.head()
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 12  17:45:00    Thursday              18-30          Male  Junior high school
# 13  17:45:00    Thursday              31-50          Male  Junior high school
# 14  17:45:00    Thursday              31-50          Male  Junior high school
#
#    Vehicle_driver_relation  Driving_experience      Type_of_vehicle  \
# 8                 Employee                  10      Lorry (41?100Q)
# 9                 Employee                   1           Automobile
# 12                Employee                   1  Public (> 45 seats)
# 13                Employee                   5      Lorry (41?100Q)
# 14                Employee                  10           Automobile
#
#    Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.describe()
# Out:
#        Driving_experience  Number_of_vehicles_involved  Number_of_casualties
# count         2889.000000                  2889.000000           2889.000000
# mean             4.314296                     2.011076              1.529249
# std              3.281391                     0.635308              0.993012
# min              1.000000                     1.000000              1.000000
# 25%              1.000000                     2.000000              1.000000
# 50%              5.000000                     2.000000              1.000000
# 75%              5.000000                     2.000000              2.000000
# max             10.000000                     7.000000              8.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2889 entries, 8 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         2889 non-null   object
#  1   Day_of_week                  2889 non-null   object
#  2   Age_band_of_driver           2889 non-null   object
#  3   Sex_of_driver                2889 non-null   object
#  4   Educational_level            2889 non-null   object
#  5   Vehicle_driver_relation      2889 non-null   object
#  6   Driving_experience           2889 non-null   int64
#  7   Type_of_vehicle              2889 non-null   object
#  8   Owner_of_vehicle             2889 non-null   object
#  9   Service_year_of_vehicle      2889 non-null   object
#  10  Defect_of_vehicle            2889 non-null   object
#  11  Area_accident_occured        2889 non-null   object
#  12  Lanes_or_Medians             2889 non-null   object
# ...

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
f = (df.loc[:,['Number_of_casualties','Number_of_vehicles_involved','Time']]
     .applymap(lambda v: int(v) if isinstance(v, str) and v.isdecimal() else np.nan)
     .dropna()
     .corr())

sns.heatmap(f, annot=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <Axes: >

# %%
cause_counts = df['Cause_of_accident'].value_counts()
plt.figure(figsize=(8, 10))
plt.pie(cause_counts, labels=cause_counts.index, autopct='%1.1f%%', startangle=45)
plt.title('Distribution of Causes of Accidents')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.title('Distribution of Number of Casualties by Accident Severity')
sns.violinplot(data=df, x='Accident_severity', y='Number_of_casualties')
plt.xlabel('Accident Severity')
plt.ylabel('Number of Casualties')
plt.show()

# %%
df.plot.scatter(x='Age_band_of_driver', y='Accident_severity', c='Number_of_casualties', cmap='viridis')
# Out:
# <Axes: xlabel='Age_band_of_driver', ylabel='Accident_severity'>

# %%
plt.figure(figsize=(10, 6))
plt.title('Accidents by Day of the Week')
sns.histplot(data=df, x='Day_of_week')
plt.xlabel('Day of the Week')
plt.ylabel('Frequency')
plt.show()

# %%
pokemon = pd.DataFrame(df)
pokemon.plot.hexbin(x='Number_of_vehicles_involved', y='Number_of_casualties', title="hixbin Plot of Age band of driver vs Number of casualties" , gridsize=15)
plt.show()

# %%
plt.figure(figsize=(10, 6))
pd.crosstab(df['Age_band_of_driver'], df['Accident_severity']).plot(kind='bar', figsize=(10,6))
plt.title('Relationship between Age Band of Drivers and Accident Severity')
plt.xlabel('Age Band of Drivers')
plt.ylabel('Count')
plt.legend(title='Accident Severity')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# By looking at the data, it's clear that this is a pretty comprehensive dataset on road traffic accidents. 32 columns Seems like it covers all sorts of information, from time counts to accident causes and driver,victim profiles.
#
# Analyzing this data could reveal some really valuable insights. We might be able to identify common accident patterns, understand the key factors behind these incidents, and use that knowledge to develop more targeted safety interventions.
#
# The data could also provide a strong foundation for data-driven decision-making on road safety. Policymakers and authorities could use these insights to monitor trends and evaluate the effectiveness of their programs.
#
# also sharing these learnings with other regions facing similar challenges could foster greater international cooperation and knowledge exchange.
